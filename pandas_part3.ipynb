# %% [markdown]
# ## How to use groupby in pandas

# %%
import pandas as pd

# %%
#drinks = pd.read_csv('http://bit.ly/drinksbycountry')    # online csv file path
drinks = pd.read_csv('dataset/drinks.csv')

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# ...

# %%
drinks.columnsAf
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.shape
# Out:
# (193, 6)

# %%
#pd.read_table('http://bit.ly/movieusers',header=None,sep='|').head()
d=pd.read_csv('http://bit.ly/drinksbycountry',header=None)
d.head()
# Out:
#              0              1                2              3  \
# 0      country  beer_servings  spirit_servings  wine_servings
# 1  Afghanistan              0                0              0
# 2      Albania             89              132             54
# 3      Algeria             25                0             14
# 4      Andorra            245              138            312
#
#                               4          5
# 0  total_litres_of_pure_alcohol  continent
# 1                           0.0       Asia
# 2                           4.9     Europe
# 3                           0.7     Africa
# 4                          12.4     Europe

# %%
drinks[drinks.continent=='South America']
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 6    Argentina            193               25            221
# 20     Bolivia            167               41              8
# 23      Brazil            245              145             16
# 35       Chile            130              124            172
# 37    Colombia            159               76              3
# 52     Ecuador            162               74              3
# 72      Guyana             93              302              1
# 132   Paraguay            213              117             74
# 133       Peru            163              160             21
# 163   Suriname            128              178              7
# 185    Uruguay            115               35            220
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 6                             8.3  South America
# 20                            3.8  South America
# ...

# %%
drinks.loc[23,'beer_servings']
# Out:
# 245

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks[(drinks.beer_servings>17) & (drinks.beer_servings<27)]
# Out:
#           country  beer_servings  spirit_servings  wine_servings  \
# 2         Algeria             25                0             14
# 7         Armenia             21              179             11
# 10     Azerbaijan             21               46              5
# 19         Bhutan             23                0              0
# 26   Burkina Faso             25                7              7
# 56        Eritrea             18                0              0
# 58       Ethiopia             20                3              0
# 89       Kiribati             21               34              1
# 94        Lebanon             20               55             31
# 96        Liberia             19              152              2
# 100    Madagascar             26               15              4
# 127          Oman             22               16              1
# 153  Sierra Leone             25                3              2
# ...

# %%
drinks.beer_servings.sort
# Out:
# <bound method Series.sort of 0        0
# 1       89
# 2       25
# 3      245
# 4      217
# 5      102
# 6      193
# 7       21
# 8      261
# 9      279
# 10      21
# 11     122
# 12      42
# 13       0
# 14     143
# 15     142
# 16     295
# 17     263
# 18      34
# 19      23
# 20     167
# 21      76
# 22     173
# 23     245
# 24      31
# 25     231
# 26      25
# 27      88
# 28      37
# 29     144
#       ...
# 163    128
# 164     90
# 165    152
# 166    185
# 167      5
# 168      2
# 169     99
# 170    106
# 171      1
# 172     36
# 173     36
# 174    197
# 175     51
# 176     51
# 177     19
# 178      6
# 179     45
# 180    206
# 181     16
# 182    219
# 183     36
# 184    249
# 185    115
# 186     25
# 187     21
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# Name: beer_servings, dtype: int64>

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks[drinks.continent=='Africa'].beer_servings.mean()
# Out:
# 61.471698113207545

# %%
drinks.groupby('continent').beer_servings.agg(['count','min','max','mean'])
# Out:
#                count  min  max        mean
# continent
# Africa            53    0  376   61.471698
# Asia              44    0  247   37.045455
# Europe            45    0  361  193.777778
# North America     23    1  285  145.434783
# Oceania           16    0  306   89.687500
# South America     12   93  333  175.083333

# %%
drinks.groupby('continent').mean()
#drinks
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
# %matplotlib inline

# %%
drinks.groupby('continent').mean().plot(kind='bar')
