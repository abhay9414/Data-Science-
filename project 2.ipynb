# %% [markdown]
#  # load iris flower datasets

# %%
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %%
iris=load_iris()

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)

# %%
df['target']=[iris.target_names[i] for i in iris.target]

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# # Create a pairplot of dataset.. which flower species seems to be most seperated?

# %%
sn.pairplot(df,hue='target')

# %% [markdown]
# # Split dataset into train set and testing set

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('target',axis=1) # feature
y=iris.target #target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3)

# %%
x_train.shape
# Out:
# (105, 4)

# %%
x_test.shape
# Out:
# (45, 4)

# %% [markdown]
# # Train a model
# tarin svm classification with training data

# %%
from sklearn.svm import SVC
svc_model=SVC()

# %%
svc_model.fit(x_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
